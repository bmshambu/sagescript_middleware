# %%
import os
import psycopg
from psycopg.rows import dict_row
#from config import AppConfig
#cfg =AppConfig()
import os


database_url=""
def get_connection():
    return psycopg.connect(
        database_url,
        row_factory=dict_row
    )

# %%
from tools.save_job import save_scheduled_job
#from rq_config import test_generation_queue
from tools.extract_rows import extract_test_cases
from tools.priority_summary import summarize_test_case_priorities
from psycopg.rows import dict_row
from db import get_connection as get_db

def get_job_results(job_id: str):
    # Fetch job from mock DBasync def create_project(req: CreateProjectRequest, request: Request):
    conn = get_connection()
    print(f"Fetching results for job_id: {job_id}")
    try:
        with conn.cursor() as cursor:
            # 1️⃣ Fetch functional test cases for the job
            cursor.execute(
                """
                SELECT
                    ftc.test_case_id,
                    ftc.result
                FROM function_test_cases ftc
                WHERE ftc.job_id = %s
                """,
                (job_id,),
            )
            functional_rows = cursor.fetchall()

            # 2️⃣ Extract test cases
            #test_cases = extract_test_cases(functional_rows)
            #print("Extracted Test Cases:", test_cases)
            results_payloads = [row["result"] for row in functional_rows]
            test_cases = extract_test_cases(results_payloads)
            # 4️⃣ Summarize priorities
            summary = summarize_test_case_priorities(test_cases)

            # 5️⃣ Fetch automation scripts for the job
            cursor.execute(
                """
                SELECT
                    ascr.script
                FROM automation_scripts ascr
                JOIN user_stories us ON ascr.user_story_id = us.user_story_id
                WHERE us.job_id = %s
                """,
                (job_id,),
            )
            automation_rows = cursor.fetchall()

            # 6️⃣ Process automation scripts
            # dict comprehension to store scripts by their 

            automation_scripts = automation_rows[0]["script"] if automation_rows else {}



            # automation_scripts = {
            #     row["automation_id"]: row["script"] for row in automation_rows
            # }
            # automation_scripts = automation_scripts[]
   
            # 3️⃣ Fetch job info
            cursor.execute(
                """
                SELECT
                    job_id,
                    project_name,
                    description,
                    status,
                    submitted_at
                FROM scheduled_jobs
                WHERE job_id = %s
                """,
                (job_id,),
            )   
            job = cursor.fetchone() 
            STATUS_MAP = {
                "IN_QUEUE": "In Queue",
                "IN_PROGRESS": "In Progress",
                "COMPLETED": "Completed",
                "FAILED": "Failed"
            }
            
            job_info= {
                "job_id": job_id,
                "project_name": job["project_name"],
                "description": job["description"],
                "status": STATUS_MAP.get(job["status"], "In Queue"),
                "submitted_at": job["submitted_at"],
                "test_count": len(test_cases)
            }

            return {
                "high_priority_count": summary.get("high", 0),
                "medium_priority_count": summary.get("medium", 0),
                "low_priority_count": summary.get("low", 0),
                "test_cases": test_cases,
                "automation_scripts": automation_scripts,
                "job_info": job_info
            }

    finally:
        conn.close()

# %%
ans=get_job_results("23")
# Out:
# Fetching results for job_id: 23
# Priority Summary - High: 6, Medium: 4, Low: 0

# %%
ans
# Out:
# {'high_priority_count': 6,
#  'medium_priority_count': 4,
#  'low_priority_count': 0,
#  'test_cases': [{'ID': 'C1001',
#    'Type': 'positive',
#    'Steps': "1. Enter 'testuser@example.com' into the email field.\n2. Enter 'Password123!' into the password field.\n3. Click the 'Login' button.",
#    'Title': 'Verify successful login with valid credentials',
#    'Priority': 'High',
#    'TestData': {'Inputs': {'email': 'testuser@example.com',
#      'password': 'Password123!'},
#     'DB_Mock': {'users': {'email': 'testuser@example.com',
#       'password_hash': 'hashed_password_of_Password123!'}},
#     'API_Payload': {'email': 'testuser@example.com',
#      'password': 'Password123!'}},
#    'Preconditions': "A registered user 'testuser@example.com' with password 'Password123!' exists in the system. User is on the login page.",
#    'Expected Results': 'User is successfully authenticated and redirected to the dashboard page. The dashboard header or a specific dashboard element is visible.'},
#   {'ID': 'C1002',
#    'Type': 'negative',
#    'Steps': "1. Enter 'testuser@example.com' into the email field.\n2. Enter 'WrongPassword123' into the password field.\n3. Click the 'Login' button.",
#    'Title': 'Verify login with incorrect password',
#    'Priority': 'High',
#    'TestData': {'Inputs': {'email': 'testuser@example.com',
#      'password': 'WrongPassword123'},
#     'DB_Mock': {'users': {'email': 'testuser@example.com',
#       'password_hash': 'hashed_password_of_Password123!'}},
#     'API_Payload': {'email': 'testuser@example.com',
#      'password': 'WrongPassword123'}},
#    'Preconditions': "A registered user 'testuser@example.com' exists in the system. User is on the login page.",
#    'Expected Results': "User remains on the login page. An error message 'Invalid email or password.' is displayed."},
#   {'ID': 'C1003',
#    'Type': 'negative',
#    'Steps': "1. Enter 'nonexistent@example.com' into the email field.\n2. Enter 'AnyPassword123!' into the password field.\n3. Click the 'Login' button.",
#    'Title': 'Verify login with non-existent email',
#    'Priority': 'High',
#    'TestData': {'Inputs': {'email': 'nonexistent@example.com',
#      'password': 'AnyPassword123!'},
#     'DB_Mock': {'users': {}},
#     'API_Payload': {'email': 'nonexistent@example.com',
#      'password': 'AnyPassword123!'}},
#    'Preconditions': 'User is on the login page.',
#    'Expected Results': "User remains on the login page. An error message 'Invalid email or password.' is displayed."},
#   {'ID': 'C1004',
#    'Type': 'negative',
#    'Steps': "1. Enter 'invalid-email-format' into the email field.\n2. Enter 'Password123!' into the password field.\n3. Click the 'Login' button.",
#    'Title': 'Verify login with invalid email format',
#    'Priority': 'Medium',
#    'TestData': {'Inputs': {'email': 'invalid-email-format',
#      'password': 'Password123!'},
#     'DB_Mock': {},
#     'API_Payload': {'email': 'invalid-email-format',
#      'password': 'Password123!'}},
#    'Preconditions': 'User is on the login page.',
#    'Expected Results': "User remains on the login page. An error message 'Please enter a valid email address.' is displayed."},
#   {'ID': 'C1005',
#    'Type': 'negative',
#    'Steps': "1. Leave the email field empty.\n2. Enter 'Password123!' into the password field.\n3. Click the 'Login' button.",
#    'Title': 'Verify login with empty email field',
#    'Priority': 'High',
#    'TestData': {'Inputs': {'email': '', 'password': 'Password123!'},
#     'DB_Mock': {},
#     'API_Payload': {'email': '', 'password': 'Password123!'}},
#    'Preconditions': 'User is on the login page.',
#    'Expected Results': "User remains on the login page. An error message 'Email is required.' is displayed."},
#   {'ID': 'C1006',
#    'Type': 'negative',
#    'Steps': "1. Enter 'testuser@example.com' into the email field.\n2. Leave the password field empty.\n3. Click the 'Login' button.",
#    'Title': 'Verify login with empty password field',
#    'Priority': 'High',
#    'TestData': {'Inputs': {'email': 'testuser@example.com', 'password': ''},
#     'DB_Mock': {},
#     'API_Payload': {'email': 'testuser@example.com', 'password': ''}},
#    'Preconditions': 'User is on the login page.',
#    'Expected Results': "User remains on the login page. An error message 'Password is required.' is displayed."},
#   {'ID': 'C1007',
#    'Type': 'negative',
#    'Steps': "1. Leave the email field empty.\n2. Leave the password field empty.\n3. Click the 'Login' button.",
#    'Title': 'Verify login with both email and password fields empty',
#    'Priority': 'High',
#    'TestData': {'Inputs': {'email': '', 'password': ''},
#     'DB_Mock': {},
#     'API_Payload': {'email': '', 'password': ''}},
#    'Preconditions': 'User is on the login page.',
#    'Expected Results': "User remains on the login page. Error messages 'Email is required.' and 'Password is required.' are displayed."},
#   {'ID': 'C1008',
#    'Type': 'edge',
#    'Steps': "1. Enter 'verylongemailaddressforatestuserthatisvalid@example.com' into the email field.\n2. Enter 'Password123!' into the password field.\n3. Click the 'Login' button.",
#    'Title': 'Verify login with email at maximum allowed length (60 characters)',
#    'Priority': 'Medium',
#    'TestData': {'Inputs': {'email': 'verylongemailaddressforatestuserthatisvalid@example.com',
#      'password': 'Password123!'},
#     'DB_Mock': {'users': {'email': 'verylongemailaddressforatestuserthatisvalid@example.com',
#       'password_hash': 'hashed_password_of_Password123!'}},
#     'API_Payload': {'email': 'verylongemailaddressforatestuserthatisvalid@example.com',
#      'password': 'Password123!'}},
#    'Preconditions': "A registered user 'verylongemailaddressforatestuserthatisvalid@example.com' with password 'Password123!' exists. User is on the login page.",
#    'Expected Results': 'User is successfully authenticated and redirected to the dashboard page.'},
#   {'ID': 'C1009',
#    'Type': 'edge',
#    'Steps': "1. Enter 'verylongemailaddressforatestuserthatisvalidandtoolong@example.com' into the email field.\n2. Enter 'Password123!' into the password field.\n3. Click the 'Login' button.",
#    'Title': 'Verify login with email exceeding maximum allowed length (61 characters)',
#    'Priority': 'Medium',
#    'TestData': {'Inputs': {'email': 'verylongemailaddressforatestuserthatisvalidandtoolong@example.com',
#      'password': 'Password123!'},
#     'DB_Mock': {},
#     'API_Payload': {'email': 'verylongemailaddressforatestuserthatisvalidandtoolong@example.com',
#      'password': 'Password123!'}},
#    'Preconditions': 'User is on the login page.',
#    'Expected Results': "The email field should prevent input beyond 60 characters, or an error message 'Email address is too long.' should be displayed upon submission. User remains on the login page."},
#   {'ID': 'C1010',
#    'Type': 'edge',
#    'Steps': "1. Enter '  testuser@example.com  ' into the email field.\n2. Enter 'Password123!' into the password field.\n3. Click the 'Login' button.",
#    'Title': 'Verify login with email containing leading/trailing spaces',
#    'Priority': 'Medium',
#    'TestData': {'Inputs': {'email': '  testuser@example.com  ',
#      'password': 'Password123!'},
#     'DB_Mock': {'users': {'email': 'testuser@example.com',
#       'password_hash': 'hashed_password_of_Password123!'}},
#     'API_Payload': {'email': 'testuser@example.com',
#      'password': 'Password123!'}},
#    'Preconditions': "A registered user 'testuser@example.com' with password 'Password123!' exists. User is on the login page.",
#    'Expected Results': 'The system should trim leading/trailing spaces from the email. User is successfully authenticated and redirected to the dashboard page.'}],
#  'automation_scripts': {'C1001': {'script': ['import org.openqa.selenium.By;',
#     'import org.openqa.selenium.WebDriver;',
#     'import org.openqa.selenium.WebElement;',
#     'import org.openqa.selenium.chrome.ChromeDriver;',
#     'import org.junit.Assert;',
#     'import org.openqa.selenium.support.ui.ExpectedConditions;',
#     'import org.openqa.selenium.support.ui.WebDriverWait;',
#     'import java.time.Duration;',
#     '',
#     'public class LoginTest {',
#     '    public static void main(String[] args) {',
#     '        WebDriver driver = new ChromeDriver();',
#     '        driver.manage().window().maximize();',
#     '        driver.get("https://example.com/login");',
#     '',
#     '        try {',
#     '            WebElement emailField = driver.findElement(By.id("email"));',
#     '            WebElement passwordField = driver.findElement(By.id("password"));',
#     '            WebElement loginButton = driver.findElement(By.id("loginButton"));',
#     '',
#     '            emailField.sendKeys("testuser@example.com");',
#     '            passwordField.sendKeys("Password123!");',
#     '            loginButton.click();',
#     '',
#     '            WebDriverWait wait = new WebDriverWait(driver, Duration.ofSeconds(10));',
#     '            wait.until(ExpectedConditions.urlContains("/dashboard"));',
#     '            WebElement dashboardHeader = wait.until(ExpectedConditions.visibilityOfElementLocated(By.id("dashboardHeader")));',
#     '',
#     '            Assert.assertTrue("Dashboard header should be visible", dashboardHeader.isDisplayed());',
#     '            System.out.println("C1001: Passed - Successfully logged in and redirected to dashboard.");',
#     '        } catch (Exception e) {',
#     '            System.err.println("C1001: Failed - " + e.getMessage());',
#     '            Assert.fail("C1001: Test failed due to exception: " + e.getMessage());',
#     '        } finally {',
#     '            driver.quit();',
#     '        }',
#     '    }',
#     '}'],
#    'framework': 'java_selenium'},
#   'C1002': {'script': ['import org.openqa.selenium.By;',
#     'import org.openqa.selenium.WebDriver;',
#     'import org.openqa.selenium.WebElement;',
#     'import org.openqa.selenium.chrome.ChromeDriver;',
#     'import org.junit.Assert;',
#     'import org.openqa.selenium.support.ui.ExpectedConditions;',
#     'import org.openqa.selenium.support.ui.WebDriverWait;',
#     'import java.time.Duration;',
#     '',
#     'public class LoginTest {',
#     '    public static void main(String[] args) {',
#     '        WebDriver driver = new ChromeDriver();',
#     '        driver.manage().window().maximize();',
#     '        driver.get("https://example.com/login");',
#     '',
#     '        try {',
#     '            WebElement emailField = driver.findElement(By.id("email"));',
#     '            WebElement passwordField = driver.findElement(By.id("password"));',
#     '            WebElement loginButton = driver.findElement(By.id("loginButton"));',
#     '',
#     '            emailField.sendKeys("testuser@example.com");',
#     '            passwordField.sendKeys("WrongPassword123");',
#     '            loginButton.click();',
#     '',
#     '            WebDriverWait wait = new WebDriverWait(driver, Duration.ofSeconds(10));',
#     '            WebElement errorMessage = wait.until(ExpectedConditions.visibilityOfElementLocated(By.id("errorMessage")));',
#     '',
#     '            Assert.assertTrue("Error message should be displayed", errorMessage.isDisplayed());',
#     '            Assert.assertEquals("Error message text is incorrect", "Invalid email or password.", errorMessage.getText());',
#     '            Assert.assertTrue("User should remain on login page", driver.getCurrentUrl().contains("/login"));',
#     '            System.out.println("C1002: Passed - Incorrect password handled correctly.");',
#     '        } catch (Exception e) {',
#     '            System.err.println("C1002: Failed - " + e.getMessage());',
#     '            Assert.fail("C1002: Test failed due to exception: " + e.getMessage());',
#     '        } finally {',
#     '            driver.quit();',
#     '        }',
#     '    }',
#     '}'],
#    'framework': 'java_selenium'},
#   'C1003': {'script': ['import org.openqa.selenium.By;',
#     'import org.openqa.selenium.WebDriver;',
#     'import org.openqa.selenium.WebElement;',
#     'import org.openqa.selenium.chrome.ChromeDriver;',
#     'import org.junit.Assert;',
#     'import org.openqa.selenium.support.ui.ExpectedConditions;',
#     'import org.openqa.selenium.support.ui.WebDriverWait;',
#     'import java.time.Duration;',
#     '',
#     'public class LoginTest {',
#     '    public static void main(String[] args) {',
#     '        WebDriver driver = new ChromeDriver();',
#     '        driver.manage().window().maximize();',
#     '        driver.get("https://example.com/login");',
#     '',
#     '        try {',
#     '            WebElement emailField = driver.findElement(By.id("email"));',
#     '            WebElement passwordField = driver.findElement(By.id("password"));',
#     '            WebElement loginButton = driver.findElement(By.id("loginButton"));',
#     '',
#     '            emailField.sendKeys("nonexistent@example.com");',
#     '            passwordField.sendKeys("AnyPassword123!");',
#     '            loginButton.click();',
#     '',
#     '            WebDriverWait wait = new WebDriverWait(driver, Duration.ofSeconds(10));',
#     '            WebElement errorMessage = wait.until(ExpectedConditions.visibilityOfElementLocated(By.id("errorMessage")));',
#     '',
#     '            Assert.assertTrue("Error message should be displayed", errorMessage.isDisplayed());',
#     '            Assert.assertEquals("Error message text is incorrect", "Invalid email or password.", errorMessage.getText());',
#     '            Assert.assertTrue("User should remain on login page", driver.getCurrentUrl().contains("/login"));',
#     '            System.out.println("C1003: Passed - Non-existent email handled correctly.");',
#     '        } catch (Exception e) {',
#     '            System.err.println("C1003: Failed - " + e.getMessage());',
#     '            Assert.fail("C1003: Test failed due to exception: " + e.getMessage());',
#     '        } finally {',
#     '            driver.quit();',
#     '        }',
#     '    }',
#     '}'],
#    'framework': 'java_selenium'},
#   'C1004': {'script': ['import org.openqa.selenium.By;',
#     'import org.openqa.selenium.WebDriver;',
#     'import org.openqa.selenium.WebElement;',
#     'import org.openqa.selenium.chrome.ChromeDriver;',
#     'import org.junit.Assert;',
#     'import org.openqa.selenium.support.ui.ExpectedConditions;',
#     'import org.openqa.selenium.support.ui.WebDriverWait;',
#     'import java.time.Duration;',
#     '',
#     'public class LoginTest {',
#     '    public static void main(String[] args) {',
#     '        WebDriver driver = new ChromeDriver();',
#     '        driver.manage().window().maximize();',
#     '        driver.get("https://example.com/login");',
#     '',
#     '        try {',
#     '            WebElement emailField = driver.findElement(By.id("email"));',
#     '            WebElement passwordField = driver.findElement(By.id("password"));',
#     '            WebElement loginButton = driver.findElement(By.id("loginButton"));',
#     '',
#     '            emailField.sendKeys("invalid-email-format");',
#     '            passwordField.sendKeys("Password123!");',
#     '            loginButton.click();',
#     '',
#     '            WebDriverWait wait = new WebDriverWait(driver, Duration.ofSeconds(10));',
#     '            WebElement errorMessage = wait.until(ExpectedConditions.visibilityOfElementLocated(By.id("emailError"))); // Assuming specific error for email format',
#     '',
#     '            Assert.assertTrue("Error message should be displayed", errorMessage.isDisplayed());',
#     '            Assert.assertEquals("Error message text is incorrect", "Please enter a valid email address.", errorMessage.getText());',
#     '            Assert.assertTrue("User should remain on login page", driver.getCurrentUrl().contains("/login"));',
#     '            System.out.println("C1004: Passed - Invalid email format handled correctly.");',
#     '        } catch (Exception e) {',
#     '            System.err.println("C1004: Failed - " + e.getMessage());',
#     '            Assert.fail("C1004: Test failed due to exception: " + e.getMessage());',
#     '        } finally {',
#     '            driver.quit();',
#     '        }',
#     '    }',
#     '}'],
#    'framework': 'java_selenium'},
#   'C1005': {'script': ['import org.openqa.selenium.By;',
#     'import org.openqa.selenium.WebDriver;',
#     'import org.openqa.selenium.WebElement;',
#     'import org.openqa.selenium.chrome.ChromeDriver;',
#     'import org.junit.Assert;',
#     'import org.openqa.selenium.support.ui.ExpectedConditions;',
#     'import org.openqa.selenium.support.ui.WebDriverWait;',
#     'import java.time.Duration;',
#     '',
#     'public class LoginTest {',
#     '    public static void main(String[] args) {',
#     '        WebDriver driver = new ChromeDriver();',
#     '        driver.manage().window().maximize();',
#     '        driver.get("https://example.com/login");',
#     '',
#     '        try {',
#     '            WebElement emailField = driver.findElement(By.id("email"));',
#     '            WebElement passwordField = driver.findElement(By.id("password"));',
#     '            WebElement loginButton = driver.findElement(By.id("loginButton"));',
#     '',
#     '            emailField.sendKeys("");',
#     '            passwordField.sendKeys("Password123!");',
#     '            loginButton.click();',
#     '',
#     '            WebDriverWait wait = new WebDriverWait(driver, Duration.ofSeconds(10));',
#     '            WebElement errorMessage = wait.until(ExpectedConditions.visibilityOfElementLocated(By.id("emailError"))); // Assuming specific error for empty email',
#     '',
#     '            Assert.assertTrue("Error message should be displayed", errorMessage.isDisplayed());',
#     '            Assert.assertEquals("Error message text is incorrect", "Email is required.", errorMessage.getText());',
#     '            Assert.assertTrue("User should remain on login page", driver.getCurrentUrl().contains("/login"));',
#     '            System.out.println("C1005: Passed - Empty email field handled correctly.");',
#     '        } catch (Exception e) {',
#     '            System.err.println("C1005: Failed - " + e.getMessage());',
#     '            Assert.fail("C1005: Test failed due to exception: " + e.getMessage());',
#     '        } finally {',
#     '            driver.quit();',
#     '        }',
#     '    }',
#     '}'],
#    'framework': 'java_selenium'},
#   'C1006': {'script': ['import org.openqa.selenium.By;',
#     'import org.openqa.selenium.WebDriver;',
#     'import org.openqa.selenium.WebElement;',
#     'import org.openqa.selenium.chrome.ChromeDriver;',
#     'import org.junit.Assert;',
#     'import org.openqa.selenium.support.ui.ExpectedConditions;',
#     'import org.openqa.selenium.support.ui.WebDriverWait;',
#     'import java.time.Duration;',
#     '',
#     'public class LoginTest {',
#     '    public static void main(String[] args) {',
#     '        WebDriver driver = new ChromeDriver();',
#     '        driver.manage().window().maximize();',
#     '        driver.get("https://example.com/login");',
#     '',
#     '        try {',
#     '            WebElement emailField = driver.findElement(By.id("email"));',
#     '            WebElement passwordField = driver.findElement(By.id("password"));',
#     '            WebElement loginButton = driver.findElement(By.id("loginButton"));',
#     '',
#     '            emailField.sendKeys("testuser@example.com");',
#     '            passwordField.sendKeys("");',
#     '            loginButton.click();',
#     '',
#     '            WebDriverWait wait = new WebDriverWait(driver, Duration.ofSeconds(10));',
#     '            WebElement errorMessage = wait.until(ExpectedConditions.visibilityOfElementLocated(By.id("passwordError"))); // Assuming specific error for empty password',
#     '',
#     '            Assert.assertTrue("Error message should be displayed", errorMessage.isDisplayed());',
#     '            Assert.assertEquals("Error message text is incorrect", "Password is required.", errorMessage.getText());',
#     '            Assert.assertTrue("User should remain on login page", driver.getCurrentUrl().contains("/login"));',
#     '            System.out.println("C1006: Passed - Empty password field handled correctly.");',
#     '        } catch (Exception e) {',
#     '            System.err.println("C1006: Failed - " + e.getMessage());',
#     '            Assert.fail("C1006: Test failed due to exception: " + e.getMessage());',
#     '        } finally {',
#     '            driver.quit();',
#     '        }',
#     '    }',
#     '}'],
#    'framework': 'java_selenium'},
#   'C1007': {'script': ['import org.openqa.selenium.By;',
#     'import org.openqa.selenium.WebDriver;',
#     'import org.openqa.selenium.WebElement;',
#     'import org.openqa.selenium.chrome.ChromeDriver;',
#     'import org.junit.Assert;',
#     'import org.openqa.selenium.support.ui.ExpectedConditions;',
#     'import org.openqa.selenium.support.ui.WebDriverWait;',
#     'import java.time.Duration;',
#     '',
#     'public class LoginTest {',
#     '    public static void main(String[] args) {',
#     '        WebDriver driver = new ChromeDriver();',
#     '        driver.manage().window().maximize();',
#     '        driver.get("https://example.com/login");',
#     '',
#     '        try {',
#     '            WebElement emailField = driver.findElement(By.id("email"));',
#     '            WebElement passwordField = driver.findElement(By.id("password"));',
#     '            WebElement loginButton = driver.findElement(By.id("loginButton"));',
#     '',
#     '            emailField.sendKeys("");',
#     '            passwordField.sendKeys("");',
#     '            loginButton.click();',
#     '',
#     '            WebDriverWait wait = new WebDriverWait(driver, Duration.ofSeconds(10));',
#     '            WebElement emailErrorMessage = wait.until(ExpectedConditions.visibilityOfElementLocated(By.id("emailError")));',
#     '            WebElement passwordErrorMessage = wait.until(ExpectedConditions.visibilityOfElementLocated(By.id("passwordError")));',
#     '',
#     '            Assert.assertTrue("Email error message should be displayed", emailErrorMessage.isDisplayed());',
#     '            Assert.assertEquals("Email error message text is incorrect", "Email is required.", emailErrorMessage.getText());',
#     '            Assert.assertTrue("Password error message should be displayed", passwordErrorMessage.isDisplayed());',
#     '            Assert.assertEquals("Password error message text is incorrect", "Password is required.", passwordErrorMessage.getText());',
#     '            Assert.assertTrue("User should remain on login page", driver.getCurrentUrl().contains("/login"));',
#     '            System.out.println("C1007: Passed - Both empty fields handled correctly.");',
#     '        } catch (Exception e) {',
#     '            System.err.println("C1007: Failed - " + e.getMessage());',
#     '            Assert.fail("C1007: Test failed due to exception: " + e.getMessage());',
#     '        } finally {',
#     '            driver.quit();',
#     '        }',
#     '    }',
#     '}'],
#    'framework': 'java_selenium'},
#   'C1008': {'script': ['import org.openqa.selenium.By;',
#     'import org.openqa.selenium.WebDriver;',
#     'import org.openqa.selenium.WebElement;',
#     'import org.openqa.selenium.chrome.ChromeDriver;',
#     'import org.junit.Assert;',
#     'import org.openqa.selenium.support.ui.ExpectedConditions;',
#     'import org.openqa.selenium.support.ui.WebDriverWait;',
#     'import java.time.Duration;',
#     '',
#     'public class LoginTest {',
#     '    public static void main(String[] args) {',
#     '        WebDriver driver = new ChromeDriver();',
#     '        driver.manage().window().maximize();',
#     '        driver.get("https://example.com/login");',
#     '',
#     '        try {',
#     '            WebElement emailField = driver.findElement(By.id("email"));',
#     '            WebElement passwordField = driver.findElement(By.id("password"));',
#     '            WebElement loginButton = driver.findElement(By.id("loginButton"));',
#     '',
#     '            String longEmail = "verylongemailaddressforatestuserthatisvalid@example.com";',
#     '            emailField.sendKeys(longEmail);',
#     '            passwordField.sendKeys("Password123!");',
#     '            loginButton.click();',
#     '',
#     '            WebDriverWait wait = new WebDriverWait(driver, Duration.ofSeconds(10));',
#     '            wait.until(ExpectedConditions.urlContains("/dashboard"));',
#     '            WebElement dashboardHeader = wait.until(ExpectedConditions.visibilityOfElementLocated(By.id("dashboardHeader")));',
#     '',
#     '            Assert.assertTrue("Dashboard header should be visible", dashboardHeader.isDisplayed());',
#     '            System.out.println("C1008: Passed - Login with max length email successful.");',
#     '        } catch (Exception e) {',
#     '            System.err.println("C1008: Failed - " + e.getMessage());',
#     '            Assert.fail("C1008: Test failed due to exception: " + e.getMessage());',
#     '        } finally {',
#     '            driver.quit();',
#     '        }',
#     '    }',
#     '}'],
#    'framework': 'java_selenium'},
#   'C1009': {'script': ['import org.openqa.selenium.By;',
#     'import org.openqa.selenium.WebDriver;',
#     'import org.openqa.selenium.WebElement;',
#     'import org.openqa.selenium.chrome.ChromeDriver;',
#     'import org.junit.Assert;',
#     'import org.openqa.selenium.support.ui.ExpectedConditions;',
#     'import org.openqa.selenium.support.ui.WebDriverWait;',
#     'import java.time.Duration;',
#     '',
#     'public class LoginTest {',
#     '    public static void main(String[] args) {',
#     '        WebDriver driver = new ChromeDriver();',
#     '        driver.manage().window().maximize();',
#     '        driver.get("https://example.com/login");',
#     '',
#     '        try {',
#     '            WebElement emailField = driver.findElement(By.id("email"));',
#     '            WebElement passwordField = driver.findElement(By.id("password"));',
#     '            WebElement loginButton = driver.findElement(By.id("loginButton"));',
#     '',
#     '            String tooLongEmail = "verylongemailaddressforatestuserthatisvalidandtoolong@example.com";',
#     '            emailField.sendKeys(tooLongEmail);',
#     '            passwordField.sendKeys("Password123!");',
#     '            loginButton.click();',
#     '',
#     '            WebDriverWait wait = new WebDriverWait(driver, Duration.ofSeconds(10));',
#     '            WebElement errorMessage = wait.until(ExpectedConditions.visibilityOfElementLocated(By.id("emailError"))); // Assuming specific error for email length',
#     '',
#     '            Assert.assertTrue("Error message should be displayed", errorMessage.isDisplayed());',
#     '            Assert.assertEquals("Error message text is incorrect", "Email address is too long.", errorMessage.getText());',
#     '            Assert.assertTrue("User should remain on login page", driver.getCurrentUrl().contains("/login"));',
#     '            System.out.println("C1009: Passed - Email exceeding max length handled correctly.");',
#     '        } catch (Exception e) {',
#     '            System.err.println("C1009: Failed - " + e.getMessage());',
#     '            Assert.fail("C1009: Test failed due to exception: " + e.getMessage());',
#     '        } finally {',
#     '            driver.quit();',
#     '        }',
#     '    }',
#     '}'],
#    'framework': 'java_selenium'},
#   'C1010': {'script': ['import org.openqa.selenium.By;',
#     'import org.openqa.selenium.WebDriver;',
#     'import org.openqa.selenium.WebElement;',
#     'import org.openqa.selenium.chrome.ChromeDriver;',
#     'import org.junit.Assert;',
#     'import org.openqa.selenium.support.ui.ExpectedConditions;',
#     'import org.openqa.selenium.support.ui.WebDriverWait;',
#     'import java.time.Duration;',
#     '',
#     'public class LoginTest {',
#     '    public static void main(String[] args) {',
#     '        WebDriver driver = new ChromeDriver();',
#     '        driver.manage().window().maximize();',
#     '        driver.get("https://example.com/login");',
#     '',
#     '        try {',
#     '            WebElement emailField = driver.findElement(By.id("email"));',
#     '            WebElement passwordField = driver.findElement(By.id("password"));',
#     '            WebElement loginButton = driver.findElement(By.id("loginButton"));',
#     '',
#     '            emailField.sendKeys("  testuser@example.com  ");',
#     '            passwordField.sendKeys("Password123!");',
#     '            loginButton.click();',
#     '',
#     '            WebDriverWait wait = new WebDriverWait(driver, Duration.ofSeconds(10));',
#     '            wait.until(ExpectedConditions.urlContains("/dashboard"));',
#     '            WebElement dashboardHeader = wait.until(ExpectedConditions.visibilityOfElementLocated(By.id("dashboardHeader")));',
#     '',
#     '            Assert.assertTrue("Dashboard header should be visible", dashboardHeader.isDisplayed());',
#     '            System.out.println("C1010: Passed - Login with email containing leading/trailing spaces successful.");',
#     '        } catch (Exception e) {',
#     '            System.err.println("C1010: Failed - " + e.getMessage());',
#     '            Assert.fail("C1010: Test failed due to exception: " + e.getMessage());',
#     '        } finally {',
#     '            driver.quit();',
#     '        }',
#     '    }',
#     '}'],
#    'framework': 'java_selenium'}},
#  'job_info': {'job_id': '23',
#   'project_name': 'Amazon',
#   'description': 'Fun1',
#   'status': 'Completed',
#   'submitted_at': datetime.datetime(2026, 2, 9, 8, 10, 37, 762791),
#   'test_count': 10}}

# %%
def get_all_jobs():
    jobs_list = []

    conn = get_connection()
    try:
        with conn.cursor() as cursor:
            cursor.execute(
                """
                SELECT
                    sj.job_id,
                    sj.project_name,
                    sj.description,
                    sj.status,
                    sj.submitted_at,
                    COUNT(ftc.test_case_id) AS test_count
                FROM scheduled_jobs sj
                LEFT JOIN function_test_cases ftc
                    ON sj.job_id = ftc.job_id
                GROUP BY
                    sj.job_id,
                    sj.project_name,
                    sj.description,
                    sj.status,
                    sj.submitted_at
                ORDER BY sj.submitted_at DESC
                """
            )

            rows = cursor.fetchall()
            STATUS_MAP = {
                "IN_QUEUE": "In Queue",
                "IN_PROGRESS": "In Progress",
                "COMPLETED": "Completed",
                "FAILED": "Failed"
            }

            for row in rows:
                jobs_list.append(
                    {
                        "id": row["job_id"],  # UI uses this for the list
                        "project": row["project_name"],
                        "description": row["description"],
                        "status": STATUS_MAP.get(row["status"], "In Queue"),
                        # PostgreSQL returns datetime objects already
                        "submitted": row["submitted_at"].strftime("%b %d, %I:%M %p"),
                        "tests": row["test_count"],
                    }
                )

        return jobs_list

    finally:
        conn.close()

# %%
def get_all_jobs():
    jobs_list = []

    conn = get_connection()
    try:
        with conn.cursor() as cursor:
            cursor.execute(
                """
                    SELECT
                        sj.job_id,
                        sj.project_name,
                        sj.description,
                        sj.status,
                        sj.submitted_at,
                        COALESCE(
                            SUM(
                                CASE
                                    WHEN jsonb_typeof(ftc.result) = 'array'
                                    AND jsonb_typeof(ftc.result->0) = 'array'
                                    THEN jsonb_array_length(ftc.result->0)
                                    WHEN jsonb_typeof(ftc.result) = 'array'
                                    THEN jsonb_array_length(ftc.result)
                                    ELSE 0
                                END
                            ),
                            0
                        ) AS test_count
                    FROM scheduled_jobs sj
                    LEFT JOIN function_test_cases ftc
                        ON sj.job_id = ftc.job_id
                    GROUP BY
                        sj.job_id,
                        sj.project_name,
                        sj.description,
                        sj.status,
                        sj.submitted_at
                    ORDER BY sj.submitted_at DESC;
                """
            )

            rows = cursor.fetchall()
            STATUS_MAP = {
                "IN_QUEUE": "In Queue",
                "IN_PROGRESS": "In Progress",
                "COMPLETED": "Completed",
                "FAILED": "Failed"
            }

            for row in rows:
                jobs_list.append(
                    {
                        "id": row["job_id"],
                        "project": row["project_name"],
                        "description": row["description"],
                        "status": STATUS_MAP.get(row["status"], "In Queue"),
                        "submitted": row["submitted_at"].strftime("%b %d, %I:%M %p"),
                        "tests": row["test_count"],
                    }
                )

        return jobs_list

    finally:
        conn.close()

# %%
r=get_all_jobs()
# Out:
# ---------------------------------------------------------------------------
# InvalidParameterValue                     Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 r=get_all_jobs()
#
# Cell In[10], line 7, in get_all_jobs()
#       5 try:
#       6     with conn.cursor() as cursor:
# ----> 7         cursor.execute(
#       8             """
#       9             SELECT
#      10                 sj.job_id,
#      11                 sj.project_name,
#      12                 sj.description,
#      13                 sj.status,
#      14                 sj.submitted_at,
#      15                 COALESCE(SUM(jsonb_array_length(ftc.result)), 0) AS test_count
#      16             FROM scheduled_jobs sj
#      17             LEFT JOIN function_test_cases ftc
#      18                 ON sj.job_id = ftc.job_id
#      19             GROUP BY
#      20                 sj.job_id,
#      21                 sj.project_name,
#      22                 sj.description,
#      23                 sj.status,
#      24                 sj.submitted_at
#      25             ORDER BY sj.submitted_at DESC
#      26             """
#      27         )
#      29         rows = cursor.fetchall()
#      30         STATUS_MAP = {
#      31             "IN_QUEUE": "In Queue",
#      32             "IN_PROGRESS": "In Progress",
#      33             "COMPLETED": "Completed",
#      34             "FAILED": "Failed"
#      35         }
#
# File c:\GenAi_Prjcts\test_case_generation_v3\Worker\sagescript_middleware\.venv\Lib\site-packages\psycopg\cursor.py:117, in Cursor.execute(self, query, params, prepare, binary)
#     113         self._conn.wait(
#     114             self._execute_gen(query, params, prepare=prepare, binary=binary)
#     115         )
#     116 except e._NO_TRACEBACK as ex:
# --> 117     raise ex.with_traceback(None)
#     118 return self
#
# InvalidParameterValue: cannot get array length of a non-array

# %%
r
# Out:
# [{'id': 23,
#   'project': 'Amazon',
#   'description': 'Fun1',
#   'status': 'Completed',
#   'submitted': 'Feb 09, 08:10 AM',
#   'tests': 1},
#  {'id': 22,
#   'project': 'Blinkit',
#   'description': 'Functional test request for validating the user login flow.',
#   'status': 'Completed',
#   'submitted': 'Feb 09, 07:56 AM',
#   'tests': 1},
#  {'id': 21,
#   'project': 'Amazon',
#   'description': 'Functional test request for validating the user login flow',
#   'status': 'Completed',
#   'submitted': 'Feb 09, 07:33 AM',
#   'tests': 1},
#  {'id': 20,
#   'project': 'Blinkit',
#   'description': 'Functional test request for validating the user login flow',
#   'status': 'Failed',
#   'submitted': 'Feb 09, 07:09 AM',
#   'tests': 0},
#  {'id': 18,
#   'project': 'Amazon',
#   'description': 'amazon ui test',
#   'status': 'Completed',
#   'submitted': 'Feb 08, 08:17 AM',
#   'tests': 0},
#  {'id': 17,
#   'project': 'Blinkit',
#   'description': 'blinkit test ',
#   'status': 'Completed',
#   'submitted': 'Feb 07, 04:53 PM',
#   'tests': 0},
#  {'id': 16,
#   'project': 'Blinkit',
#   'description': 'project test 2 ',
#   'status': 'Completed',
#   'submitted': 'Feb 07, 02:56 PM',
#   'tests': 0},
#  {'id': 14,
#   'project': 'Authentication Service',
#   'description': 'Functional test request for validating the user login flow.',
#   'status': 'Completed',
#   'submitted': 'Feb 02, 01:07 PM',
#   'tests': 0},
#  {'id': 3,
#   'project': 'Authentication Service',
#   'description': 'Functional test request for validating the user login flow.',
#   'status': 'Completed',
#   'submitted': 'Jan 29, 12:06 PM',
#   'tests': 0},
#  {'id': 2,
#   'project': 'Sage_Script_Project_1',
#   'description': 'Authentication Service 2',
#   'status': 'Completed',
#   'submitted': 'Jan 28, 10:23 AM',
#   'tests': 0}]
